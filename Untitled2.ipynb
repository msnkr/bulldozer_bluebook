# %%
import pandas as pd
import numpy as np

from sklearn.preprocessing import LabelEncoder
from xgboost import XGBRegressor

import matplotlib.pyplot as plt
import seaborn as sns

# %%
train_df = pd.read_csv("data/Train.csv", low_memory=False, parse_dates=["saledate"])
valid_df = pd.read_csv("data/Valid.csv", low_memory=False, parse_dates=["saledate"])

# %%
train_df.head()
# Out:
#    SalesID  SalePrice  MachineID  ModelID  datasource  auctioneerID  YearMade  \
# 0  1139246      66000     999089     3157         121           3.0      2004
# 1  1139248      57000     117657       77         121           3.0      1996
# 2  1139249      10000     434808     7009         121           3.0      2001
# 3  1139251      38500    1026470      332         121           3.0      2001
# 4  1139253      11000    1057373    17311         121           3.0      2007
#
#    MachineHoursCurrentMeter UsageBand   saledate  ... Undercarriage_Pad_Width  \
# 0                      68.0       Low 2006-11-16  ...                     NaN
# 1                    4640.0       Low 2004-03-26  ...                     NaN
# 2                    2838.0      High 2004-02-26  ...                     NaN
# 3                    3486.0      High 2011-05-19  ...                     NaN
# 4                     722.0    Medium 2009-07-23  ...                     NaN
#
#   Stick_Length Thumb Pattern_Changer Grouser_Type Backhoe_Mounting Blade_Type  \
# 0          NaN   NaN             NaN          NaN              NaN        NaN
# 1          NaN   NaN             NaN          NaN              NaN        NaN
# 2          NaN   NaN             NaN          NaN              NaN        NaN
# 3          NaN   NaN             NaN          NaN              NaN        NaN
# 4          NaN   NaN             NaN          NaN              NaN        NaN
#
#   Travel_Controls Differential_Type Steering_Controls
# 0             NaN          Standard      Conventional
# 1             NaN          Standard      Conventional
# 2             NaN               NaN               NaN
# 3             NaN               NaN               NaN
# 4             NaN               NaN               NaN
#
# [5 rows x 53 columns]

# %%
train_df.sort_values(by="saledate", inplace=True)
valid_df.sort_values(by="saledate", inplace=True)

# %%
train_df.isna().sum()
# Out:
# SalesID                          0
# SalePrice                        0
# MachineID                        0
# ModelID                          0
# datasource                       0
# auctioneerID                 20136
# YearMade                         0
# MachineHoursCurrentMeter    258360
# UsageBand                   331486
# saledate                         0
# fiModelDesc                      0
# fiBaseModel                      0
# fiSecondaryDesc             137191
# fiModelSeries               344217
# fiModelDescriptor           329206
# ProductSize                 210775
# fiProductClassDesc               0
# state                            0
# ProductGroup                     0
# ProductGroupDesc                 0
# Drive_System                296764
# Enclosure                      325
# Forks                       209048
# Pad_Type                    321991
# Ride_Control                252519
# Stick                       321991
# Transmission                217895
# Turbocharged                321991
# Blade_Extension             375906
# Blade_Width                 375906
# Enclosure_Type              375906
# Engine_Horsepower           375906
# Hydraulics                   80555
# Pushblock                   375906
# Ripper                      296988
# Scarifier                   375895
# Tip_Control                 375906
# Tire_Size                   306407
# Coupler                     187173
# Coupler_System              357667
# Grouser_Tracks              357763
# Hydraulics_Flow             357763
# Track_Type                  301972
# Undercarriage_Pad_Width     301253
# Stick_Length                301907
# Thumb                       301837
# Pattern_Changer             301907
# Grouser_Type                301972
# Backhoe_Mounting            322453
# Blade_Type                  321292
# Travel_Controls             321291
# Differential_Type           331714
# Steering_Controls           331756
# dtype: int64

# %%
encoder = LabelEncoder()

def preprocessing(df):
    df["SaleMonth"] = df.saledate.dt.month
    df["SaleYear"] = df.saledate.dt.year
    df.drop("saledate", axis=1, inplace=True)
    
    for label, content in df.items():
        if pd.api.types.is_numeric_dtype(content):
            if pd.isnull(content).sum():
                df[label] = pd.isnull(content.median())
        else:
            if pd.isnull(content).sum():
                df[label] = df[label].fillna("missing")

            df[label] = encoder.fit_transform(content)
    return df

# %%
train_df = preprocessing(train_df)

# %%
train_df.isna().sum()
# Out:
# SalesID                     0
# SalePrice                   0
# MachineID                   0
# ModelID                     0
# datasource                  0
# auctioneerID                0
# YearMade                    0
# MachineHoursCurrentMeter    0
# UsageBand                   0
# fiModelDesc                 0
# fiBaseModel                 0
# fiSecondaryDesc             0
# fiModelSeries               0
# fiModelDescriptor           0
# ProductSize                 0
# fiProductClassDesc          0
# state                       0
# ProductGroup                0
# ProductGroupDesc            0
# Drive_System                0
# Enclosure                   0
# Forks                       0
# Pad_Type                    0
# Ride_Control                0
# Stick                       0
# Transmission                0
# Turbocharged                0
# Blade_Extension             0
# Blade_Width                 0
# Enclosure_Type              0
# Engine_Horsepower           0
# Hydraulics                  0
# Pushblock                   0
# Ripper                      0
# Scarifier                   0
# Tip_Control                 0
# Tire_Size                   0
# Coupler                     0
# Coupler_System              0
# Grouser_Tracks              0
# Hydraulics_Flow             0
# Track_Type                  0
# Undercarriage_Pad_Width     0
# Stick_Length                0
# Thumb                       0
# Pattern_Changer             0
# Grouser_Type                0
# Backhoe_Mounting            0
# Blade_Type                  0
# Travel_Controls             0
# Differential_Type           0
# Steering_Controls           0
# SaleMonth                   0
# SaleYear                    0
# dtype: int64

# %%
X_train, y_train = train_df.drop("SalePrice", axis=1), train_df["SalePrice"]

# %%
# %%time

bst = XGBRegressor().fit(X_train, y_train)
# Out:
# CPU times: total: 11.2 s
# Wall time: 3.74 s

# %%
bst.score(X_train, y_train)
# Out:
# 0.8942635563467005

# %%
valid_df = preprocessing(valid_df)
y_valid = bst.predict(valid_df)

# %%
valid_df["SalePrice"] = pd.Series(y_valid)
# Out:
#        SalesID  MachineID  ModelID  datasource  auctioneerID  YearMade  \
# 11351  6324811    1919104    19330         149            99      2004
# 8771   6286551    1866718     4605         149            99      2006
# 8776   6286556    1793587     4605         149            99      2006
# 4652   6256957    1860454     6868         149            99      1000
# 9754   6302984    1915521     5266         149            99      2001
#
#        MachineHoursCurrentMeter  UsageBand  fiModelDesc  fiBaseModel  ...  \
# 11351                     False          3           69           38  ...
# 8771                      False          3          201           94  ...
# 8776                      False          3          201           94  ...
# 4652                      False          3          699          257  ...
# 9754                      False          3          876          350  ...
#
#        Pattern_Changer  Grouser_Type  Backhoe_Mounting  Blade_Type  \
# 11351                3             2                 1           8
# 8771                 3             2                 1           8
# 8776                 3             2                 1           8
# 4652                 1             0                 1           8
# 9754                 3             2                 0           3
#
#        Travel_Controls  Differential_Type  Steering_Controls  SaleMonth  \
# 11351                7                  3                  3          4
# 8771                 7                  3                  3          4
# 8776                 7                  3                  3          4
# 4652                 7                  3                  3          4
# 9754                 5                  3                  3          4
#
#        SaleYear     SalePrice
# 11351      2012  15803.992188
# 8771       2012  50885.136719
# 8776       2012  32567.615234
# 4652       2012  27264.453125
# 9754       2012  87382.593750
#
# [5 rows x 54 columns]

# %%
sns.barplot(data=train_df, x="SaleYear", y="SalePrice")
plt.xticks(rotation=90);
