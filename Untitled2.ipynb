# %%
import pandas as pd
import numpy as np

from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error, mean_squared_log_error
from sklearn.model_selection import RandomizedSearchCV
from xgboost import XGBRegressor, XGBRFRegressor

import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("data/TrainAndValid.csv", low_memory=False, parse_dates=["saledate"])

# %%
df.head()
# Out:
#    SalesID  SalePrice  MachineID  ModelID  datasource  auctioneerID  YearMade  \
# 0  1139246    66000.0     999089     3157         121           3.0      2004
# 1  1139248    57000.0     117657       77         121           3.0      1996
# 2  1139249    10000.0     434808     7009         121           3.0      2001
# 3  1139251    38500.0    1026470      332         121           3.0      2001
# 4  1139253    11000.0    1057373    17311         121           3.0      2007
#
#    MachineHoursCurrentMeter UsageBand   saledate  ... Undercarriage_Pad_Width  \
# 0                      68.0       Low 2006-11-16  ...                     NaN
# 1                    4640.0       Low 2004-03-26  ...                     NaN
# 2                    2838.0      High 2004-02-26  ...                     NaN
# 3                    3486.0      High 2011-05-19  ...                     NaN
# 4                     722.0    Medium 2009-07-23  ...                     NaN
#
#   Stick_Length Thumb Pattern_Changer Grouser_Type Backhoe_Mounting Blade_Type  \
# 0          NaN   NaN             NaN          NaN              NaN        NaN
# 1          NaN   NaN             NaN          NaN              NaN        NaN
# 2          NaN   NaN             NaN          NaN              NaN        NaN
# 3          NaN   NaN             NaN          NaN              NaN        NaN
# 4          NaN   NaN             NaN          NaN              NaN        NaN
#
#   Travel_Controls Differential_Type Steering_Controls
# 0             NaN          Standard      Conventional
# 1             NaN          Standard      Conventional
# 2             NaN               NaN               NaN
# 3             NaN               NaN               NaN
# 4             NaN               NaN               NaN
#
# [5 rows x 53 columns]

# %%
df.sort_values(by="saledate", inplace=True)

# %%
df.isna().sum()
# Out:
# SalesID                          0
# SalePrice                        0
# MachineID                        0
# ModelID                          0
# datasource                       0
# auctioneerID                 20136
# YearMade                         0
# MachineHoursCurrentMeter    265194
# UsageBand                   339028
# saledate                         0
# fiModelDesc                      0
# fiBaseModel                      0
# fiSecondaryDesc             140727
# fiModelSeries               354031
# fiModelDescriptor           337882
# ProductSize                 216605
# fiProductClassDesc               0
# state                            0
# ProductGroup                     0
# ProductGroupDesc                 0
# Drive_System                305611
# Enclosure                      334
# Forks                       214983
# Pad_Type                    331602
# Ride_Control                259970
# Stick                       331602
# Transmission                224691
# Turbocharged                331602
# Blade_Extension             386715
# Blade_Width                 386715
# Enclosure_Type              386715
# Engine_Horsepower           386715
# Hydraulics                   82565
# Pushblock                   386715
# Ripper                      305753
# Scarifier                   386704
# Tip_Control                 386715
# Tire_Size                   315060
# Coupler                     192019
# Coupler_System              367724
# Grouser_Tracks              367823
# Hydraulics_Flow             367823
# Track_Type                  310505
# Undercarriage_Pad_Width     309782
# Stick_Length                310437
# Thumb                       310366
# Pattern_Changer             310437
# Grouser_Type                310505
# Backhoe_Mounting            331986
# Blade_Type                  330823
# Travel_Controls             330821
# Differential_Type           341134
# Steering_Controls           341176
# dtype: int64

# %%
encoder = LabelEncoder()

def preprocessing(df):
    df["SaleMonth"] = df.saledate.dt.month
    df["SaleYear"] = df.saledate.dt.year
    df.drop("saledate", axis=1, inplace=True)
    
    for label, content in df.items():
        if pd.api.types.is_numeric_dtype(content):
            if pd.isnull(content).sum():
                df[label] = pd.isnull(content.median())
        else:
            if pd.isnull(content).sum():
                df[label] = df[label].fillna("missing")

            df[label] = encoder.fit_transform(content)
    return df

# %%
df = preprocessing(df)

# %%
train_df = df[df.SaleYear != 2012]
valid_df = df[df.SaleYear == 2012]

# %%
len(train_df), len(valid_df)
# Out:
# (401125, 11573)

# %%
X_train, y_train = train_df.drop("SalePrice", axis=1), train_df["SalePrice"]
X_valid, y_valid = valid_df.drop("SalePrice", axis=1), valid_df["SalePrice"]

# %%
bst = XGBRegressor().fit(X_train, y_train)

# %%
bst.score(X_valid, y_valid)
# Out:
# 0.8667126162197849

# %%
def show_scores(model):
    y_preds_train = model.predict(X_train)
    y_preds_valid = model.predict(X_valid)

    scores = {
        "Test MAE": mean_absolute_error(y_train, y_preds_train),
        "Valid MAE": mean_absolute_error(y_valid, y_preds_valid),
        "TEST MSE": mean_squared_error(y_train, y_preds_train),
        "Valid MSE": mean_squared_error(y_valid, y_preds_valid),
        "Train RMSE": mean_squared_error(y_train, y_preds_train, squared=False),
        "Valid RMSE": mean_squared_error(y_valid, y_preds_valid, squared=False),
        "Train MSLE": mean_squared_log_error(y_train, y_preds_train, squared=False),
        "Valid MSLE": mean_squared_log_error(y_valid, y_preds_valid, squared=False),
        "Train R2 Score": r2_score(y_train, y_preds_train),
        "Valid R2 Score": r2_score(y_valid, y_preds_valid)
    }

    return scores

# %%
results = show_scores(bst)
results
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[59], line 1
# ----> 1 results = show_scores(bst)
#       2 results
#
# Cell In[58], line 12, in show_scores(model)
#       2 y_preds_train = model.predict(X_train)
#       3 y_preds_valid = model.predict(X_valid)
#       5 scores = {
#       6     "Test MAE": mean_absolute_error(y_train, y_preds_train),
#       7     "Valid MAE": mean_absolute_error(y_valid, y_preds_valid),
#       8     "TEST MSE": mean_squared_error(y_train, y_preds_train),
#       9     "Valid MSE": mean_squared_error(y_valid, y_preds_valid),
#      10     "Train RMSE": mean_squared_error(y_train, y_preds_train, squared=False),
#      11     "Valid RMSE": mean_squared_error(y_valid, y_preds_valid, squared=False),
# ---> 12     "Train MSLE": mean_squared_log_error(y_train, y_preds_train, squared=False),
#      13     "Valid MSLE": mean_squared_log_error(y_valid, y_preds_valid, squared=False),
#      14     "Train R2 Score": r2_score(y_train, y_preds_train),
#      15     "Valid R2 Score": r2_score(y_valid, y_preds_valid)
#      16 }
#      18 return scores
#
# File ~\miniconda3\envs\new_env\lib\site-packages\sklearn\utils\_param_validation.py:211, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     205 try:
#     206     with config_context(
#     207         skip_parameter_validation=(
#     208             prefer_skip_nested_validation or global_skip_validation
#     209         )
#     210     ):
# --> 211         return func(*args, **kwargs)
#     212 except InvalidParameterError as e:
#     213     # When the function is just a wrapper around an estimator, we allow
#     214     # the function to delegate validation to the estimator, but we replace
#     215     # the name of the estimator by the name of the function in the error
#     216     # message to avoid confusion.
#     217     msg = re.sub(
#     218         r"parameter of \w+ must be",
#     219         f"parameter of {func.__qualname__} must be",
#     220         str(e),
#     221     )
#
# File ~\miniconda3\envs\new_env\lib\site-packages\sklearn\metrics\_regression.py:567, in mean_squared_log_error(y_true, y_pred, sample_weight, multioutput, squared)
#     564 check_consistent_length(y_true, y_pred, sample_weight)
#     566 if (y_true < 0).any() or (y_pred < 0).any():
# --> 567     raise ValueError(
#     568         "Mean Squared Logarithmic Error cannot be used when "
#     569         "targets contain negative values."
#     570     )
#     572 return mean_squared_error(
#     573     np.log1p(y_true),
#     574     np.log1p(y_pred),
#    (...)
#     577     squared=squared,
#     578 )
#
# ValueError: Mean Squared Logarithmic Error cannot be used when targets contain negative values.

# %%
_, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(14, 6))
sns.barplot(data=valid_df, x="SaleMonth", y="SalePrice", ax=ax1, palette="pastel", hue="SaleMonth", legend=False)
sns.barplot(data=train_df, x="SaleMonth", y="SalePrice", ax=ax2, palette="pastel", hue="SaleMonth", legend=False);

# %%
plt.figure(figsize=(14, 6))
sns.histplot(data=valid_df, x="SalePrice", hue="SaleMonth", kde=True, palette="pastel");

# %%
plt.figure(figsize=(14, 6))
sns.histplot(data=train_df, x="SalePrice", hue="SaleMonth", kde=True, palette="pastel");

# %%
test_df = pd.read_csv("data/Test.csv", parse_dates=["saledate"], low_memory=False)
test_df.head()
# Out:
#    SalesID  MachineID  ModelID  datasource  auctioneerID  YearMade  \
# 0  1227829    1006309     3168         121             3      1999
# 1  1227844    1022817     7271         121             3      1000
# 2  1227847    1031560    22805         121             3      2004
# 3  1227848      56204     1269         121             3      2006
# 4  1227863    1053887    22312         121             3      2005
#
#    MachineHoursCurrentMeter UsageBand   saledate fiModelDesc  ...  \
# 0                    3688.0       Low 2012-05-03        580G  ...
# 1                   28555.0      High 2012-05-10         936  ...
# 2                    6038.0    Medium 2012-05-10    EC210BLC  ...
# 3                    8940.0      High 2012-05-10       330CL  ...
# 4                    2286.0       Low 2012-05-10        650K  ...
#
#   Undercarriage_Pad_Width         Stick_Length   Thumb      Pattern_Changer  \
# 0                     NaN                  NaN     NaN                  NaN
# 1                     NaN                  NaN     NaN                  NaN
# 2     None or Unspecified                9' 6"  Manual  None or Unspecified
# 3     None or Unspecified  None or Unspecified  Manual                  Yes
# 4                     NaN                  NaN     NaN                  NaN
#
#   Grouser_Type     Backhoe_Mounting Blade_Type      Travel_Controls  \
# 0          NaN                  NaN        NaN                  NaN
# 1          NaN                  NaN        NaN                  NaN
# 2       Double                  NaN        NaN                  NaN
# 3       Triple                  NaN        NaN                  NaN
# 4          NaN  None or Unspecified        PAT  None or Unspecified
#
#   Differential_Type Steering_Controls
# 0               NaN               NaN
# 1          Standard      Conventional
# 2               NaN               NaN
# 3               NaN               NaN
# 4               NaN               NaN
#
# [5 rows x 52 columns]

# %%
test_df.sort_values(by=["saledate"], inplace=True)

# %%
len(test_df)
# Out:
# 12457

# %%
test_df = preprocessing(test_df)
test_df.head()
# Out:
#       SalesID  MachineID  ModelID  datasource  auctioneerID  YearMade  \
# 1408  4317459    2295526     8132         172             1      1998
# 1023  4249784    1745722     3178         172             1      1995
# 1728  4392603    2283116    18111         172             1      2004
# 1167  4274831    2288988     3783         172             1      2001
# 1594  4362801    2300591    16490         172             1      2006
#
#       MachineHoursCurrentMeter  UsageBand  fiModelDesc  fiBaseModel  ...  \
# 1408                     False          2          396          147  ...
# 1023                     False          1          508          179  ...
# 1728                     False          1          905          319  ...
# 1167                     False          2          823          289  ...
# 1594                     False          1         1512          609  ...
#
#       Thumb  Pattern_Changer  Grouser_Type  Backhoe_Mounting  Blade_Type  \
# 1408      3                2             2                 1           8
# 1023      3                2             2                 1           8
# 1728      3                2             2                 1           8
# 1167      3                2             2                 1           8
# 1594      2                0             0                 1           8
#
#       Travel_Controls  Differential_Type  Steering_Controls  SaleMonth  \
# 1408                6                  3                  3          5
# 1023                6                  3                  3          5
# 1728                6                  3                  3          5
# 1167                6                  2                  1          5
# 1594                6                  3                  3          5
#
#       SaleYear
# 1408      2012
# 1023      2012
# 1728      2012
# 1167      2012
# 1594      2012
#
# [5 rows x 53 columns]

# %%
y_preds = bst.predict(test_df)
test_df["SalePrice"] = pd.Series(y_preds)
test_df.head()
# Out:
#       SalesID  MachineID  ModelID  datasource  auctioneerID  YearMade  \
# 1408  4317459    2295526     8132         172             1      1998
# 1023  4249784    1745722     3178         172             1      1995
# 1728  4392603    2283116    18111         172             1      2004
# 1167  4274831    2288988     3783         172             1      2001
# 1594  4362801    2300591    16490         172             1      2006
#
#       MachineHoursCurrentMeter  UsageBand  fiModelDesc  fiBaseModel  ...  \
# 1408                     False          2          396          147  ...
# 1023                     False          1          508          179  ...
# 1728                     False          1          905          319  ...
# 1167                     False          2          823          289  ...
# 1594                     False          1         1512          609  ...
#
#       Pattern_Changer  Grouser_Type  Backhoe_Mounting  Blade_Type  \
# 1408                2             2                 1           8
# 1023                2             2                 1           8
# 1728                2             2                 1           8
# 1167                2             2                 1           8
# 1594                0             0                 1           8
#
#       Travel_Controls  Differential_Type  Steering_Controls  SaleMonth  \
# 1408                6                  3                  3          5
# 1023                6                  3                  3          5
# 1728                6                  3                  3          5
# 1167                6                  2                  1          5
# 1594                6                  3                  3          5
#
#       SaleYear     SalePrice
# 1408      2012  79741.195312
# 1023      2012  51798.882812
# 1728      2012  74326.703125
# 1167      2012  38390.597656
# 1594      2012  21303.531250
#
# [5 rows x 54 columns]

# %%
sns.barplot(data=test_df, x="SaleMonth", y="SalePrice", palette="pastel", hue="SaleMonth", legend=False);

# %%
final_df = pd.concat([valid_df, train_df])
len(final_df)
# Out:
# 412698

# %%
sns.barplot(data=final_df, x="SaleMonth", y="SalePrice", palette="pastel", hue="SaleMonth", legend=False);

# %%
plt.figure(figsize=(14, 6))
sns.barplot(data=final_df, x="YearMade", y="SalePrice", hue="YearMade", palette="pastel", legend=False, width=0.5)
plt.xticks(rotation=90);

# %%
param_dist = {
    'n_estimators': range(50, 1000, 50),
    'learning_rate': [0.01, 0.05, 0.1, 0.2, 0.3],
    'max_depth': range(3, 10),
    'colsample_bytree': [i/10.0 for i in range(1, 3)],
    'gamma': [i/10.0 for i in range(3)],
    'subsample': [i/10.0 for i in range(6, 10)],
    'min_child_weight': range(1, 6),
}

# %%
# %%time
rs_bst = RandomizedSearchCV(bst, param_dist, n_iter=20, cv=5, n_jobs=-1).fit(X_train, y_train)
# Out:
# CPU times: total: 42.4 s
# Wall time: 16min 12s

# %%
rs_bst.best_params_
# Out:
# {'subsample': 0.6,
#  'n_estimators': 250,
#  'min_child_weight': 1,
#  'max_depth': 9,
#  'learning_rate': 0.1,
#  'gamma': 0.0,
#  'colsample_bytree': 0.2}

# %%
y_preds = rs_bst.predict(X_valid)

# %%
mean_squared_log_error(y_valid, y_preds, squared=False)
# Out:
# 0.2547031927207342
